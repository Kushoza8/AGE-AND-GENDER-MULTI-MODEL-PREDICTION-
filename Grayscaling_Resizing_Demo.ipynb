# %%
1+1
# Out:
# 2

# %%
path="C:/Users/LENOVO/OneDrive/Desktop/THINGS-1/blah1.png"

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image
img=Image.open(path)
img=np.array(img)
plt.axis('off')
plt.imshow(img)

# %%
img=Image.open(path)
img=img.convert('L')

# %%
plt.imshow(img)

# %%
img = img.resize((128, 128))

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=128x128>
